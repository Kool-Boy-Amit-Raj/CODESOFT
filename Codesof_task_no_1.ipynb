# %% [markdown]
# <a href="https://colab.research.google.com/github/Kool-Boy-Amit-Raj/CODESOFT/blob/main/Codesof_task_no_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
titanic_data=pd.read_csv('Titanic-Dataset.csv')
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic_data.shape
# Out:
# (891, 12)

# %%
import seaborn as sns
sns.histplot(x="Survived",data=titanic_data)
# Out:
# <Axes: xlabel='Survived', ylabel='Count'>

# %%
sns.histplot(x="Survived", hue = "Sex",data=titanic_data)
# Out:
# <Axes: xlabel='Survived', ylabel='Count'>

# %%
sns.histplot(x="Survived", hue = "Pclass",data=titanic_data)
# Out:
# <Axes: xlabel='Survived', ylabel='Count'>

# %%
titanic_data["Age"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
titanic_data["Fare"].plot.hist(bins=25,figsize=(16,8))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.histplot(x="SibSp",data=titanic_data)
# Out:
# <Axes: xlabel='SibSp', ylabel='Count'>

# %%
sns.histplot(x="Parch",data=titanic_data)
# Out:
# <Axes: xlabel='Parch', ylabel='Count'>

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(titanic_data.isnull(),yticklabels = False)
# Out:
# <Axes: >

# %%
sns.boxplot(x="Pclass",y="Age",data=titanic_data)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
titanic_data.drop(['Cabin'],axis=1).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
titanic_data.drop("Cabin",axis=1,inplace=True)

# %%
titanic_data.dropna(inplace=True)

# %%
sns.heatmap(titanic_data.isnull(),yticklabels = False)
# Out:
# <Axes: >

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
pd.get_dummies(titanic_data["Sex"])
# Out:
#      female   male
# 0     False   True
# 1      True  False
# 2      True  False
# 3      True  False
# 4     False   True
# ..      ...    ...
# 885    True  False
# 886   False   True
# 887    True  False
# 889   False   True
# 890   False   True
#
# [712 rows x 2 columns]

# %%
sex=pd.get_dummies(titanic_data["Sex"],drop_first=True)
sex.head()
# Out:
#     male
# 0   True
# 1  False
# 2  False
# 3  False
# 4   True

# %%
embark=pd.get_dummies(titanic_data["Embarked"])
embark.head()
# Out:
#        C      Q      S
# 0  False  False   True
# 1   True  False  False
# 2  False  False   True
# 3  False  False   True
# 4  False  False   True

# %%
pclass=pd.get_dummies(titanic_data["Pclass"],drop_first=True)
pclass.head()
# Out:
#        2      3
# 0  False   True
# 1  False  False
# 2  False   True
# 3  False  False
# 4  False   True

# %%
titanic_data.drop(['Sex','Embarked','PassengerId','Pclass','Name','Ticket'],axis=1,inplace=True)
titanic_data.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare
# 0         0  22.0      1      0   7.2500
# 1         1  38.0      1      0  71.2833
# 2         1  26.0      0      0   7.9250
# 3         1  35.0      1      0  53.1000
# 4         0  35.0      0      0   8.0500

# %%
titanic_data=pd.concat([titanic_data,sex,embark,pclass],axis=1)
titanic_data.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare   male      C      Q      S      2  \
# 0         0  22.0      1      0   7.2500   True  False  False   True  False
# 1         1  38.0      1      0  71.2833  False   True  False  False  False
# 2         1  26.0      0      0   7.9250  False  False  False   True  False
# 3         1  35.0      1      0  53.1000  False  False  False   True  False
# 4         0  35.0      0      0   8.0500   True  False  False   True  False
#
#        3
# 0   True
# 1  False
# 2   True
# 3  False
# 4   True

# %%
x=titanic_data.drop("Survived",axis=1)
y=titanic_data["Survived"]

# %%
from sklearn.model_selection import train_test_split

# %%
train_test_split
# Out:
# <function sklearn.model_selection._split.train_test_split(*arrays, test_size=None, train_size=None, random_state=None, shuffle=True, stratify=None)>

# %%
x_train,x_test, y_train,y_test=train_test_split(x,y,test_size=0.33)
x_train
# Out:
#       Age  SibSp  Parch     Fare   male      C      Q      S      2      3
# 649  23.0      0      0   7.5500  False  False  False   True  False   True
# 770  24.0      0      0   9.5000   True  False  False   True  False   True
# 11   58.0      0      0  26.5500  False  False  False   True  False  False
# 282  16.0      0      0   9.5000   True  False  False   True  False   True
# 631  51.0      0      0   7.0542   True  False  False   True  False   True
# ..    ...    ...    ...      ...    ...    ...    ...    ...    ...    ...
# 699  42.0      0      0   7.6500   True  False  False   True  False   True
# 255  29.0      0      2  15.2458  False   True  False  False  False   True
# 872  33.0      0      0   5.0000   True  False  False   True  False  False
# 503  37.0      0      0   9.5875  False  False  False   True  False   True
# 345  24.0      0      0  13.0000  False  False  False   True   True  False
#
# [477 rows x 10 columns]

# %%
len(x_train)
# Out:
# 477

# %%
len(x_test)
# Out:
# 235

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel=LogisticRegression()

# %%
x_train.columns = x_train.columns.astype(str)
x_test.columns = x_test.columns.astype(str)

# %%
logmodel.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
x_test
# Out:
#       Age  SibSp  Parch      Fare   male      C      Q      S      2      3
# 498  25.0      1      2  151.5500  False  False  False   True  False  False
# 96   71.0      0      0   34.6542   True   True  False  False  False  False
# 838  32.0      0      0   56.4958   True  False  False   True  False   True
# 742  21.0      2      2  262.3750  False   True  False  False  False  False
# 791  16.0      0      0   26.0000   True  False  False   True   True  False
# ..    ...    ...    ...       ...    ...    ...    ...    ...    ...    ...
# 419  10.0      0      2   24.1500  False  False  False   True  False   True
# 91   20.0      0      0    7.8542   True  False  False   True  False   True
# 325  36.0      0      0  135.6333  False   True  False  False  False  False
# 242  29.0      0      0   10.5000   True  False  False   True   True  False
# 370  25.0      1      0   55.4417   True   True  False  False  False  False
#
# [235 rows x 10 columns]

# %%
logmodel.intercept_
# Out:
# array([2.37815919])

# %%
logmodel.predict_proba(x_test)
# Out:
# array([[0.07572897, 0.92427103],
#        [0.83215998, 0.16784002],
#        [0.88434302, 0.11565698],
#        [0.0290325 , 0.9709675 ],
#        [0.5965814 , 0.4034186 ],
#        [0.38405351, 0.61594649],
#        [0.68206757, 0.31793243],
#        [0.17947721, 0.82052279],
#        [0.09016138, 0.90983862],
#        [0.91887695, 0.08112305],
#        [0.87685628, 0.12314372],
#        [0.71753057, 0.28246943],
#        [0.41067179, 0.58932821],
#        [0.86990198, 0.13009802],
#        [0.41258177, 0.58741823],
#        [0.23285608, 0.76714392],
#        [0.55105294, 0.44894706],
#        [0.97743713, 0.02256287],
#        [0.68257212, 0.31742788],
#        [0.67621428, 0.32378572],
#        [0.95850241, 0.04149759],
#        [0.31040329, 0.68959671],
#        [0.85440727, 0.14559273],
#        [0.92502257, 0.07497743],
#        [0.85658801, 0.14341199],
#        [0.12847236, 0.87152764],
#        [0.68524566, 0.31475434],
#        [0.94388223, 0.05611777],
# ...

# %%
x_test
# Out:
#       Age  SibSp  Parch      Fare   male      C      Q      S      2      3
# 498  25.0      1      2  151.5500  False  False  False   True  False  False
# 96   71.0      0      0   34.6542   True   True  False  False  False  False
# 838  32.0      0      0   56.4958   True  False  False   True  False   True
# 742  21.0      2      2  262.3750  False   True  False  False  False  False
# 791  16.0      0      0   26.0000   True  False  False   True   True  False
# ..    ...    ...    ...       ...    ...    ...    ...    ...    ...    ...
# 419  10.0      0      2   24.1500  False  False  False   True  False   True
# 91   20.0      0      0    7.8542   True  False  False   True  False   True
# 325  36.0      0      0  135.6333  False   True  False  False  False  False
# 242  29.0      0      0   10.5000   True  False  False   True   True  False
# 370  25.0      1      0   55.4417   True   True  False  False  False  False
#
# [235 rows x 10 columns]

# %%
logmodel.predict([[24.0,0,0,69.3000,0,0,0,0,0,1]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
logmodel.score(x_train,y_train)
# Out:
# 0.8343815513626834
